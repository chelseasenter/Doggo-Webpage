# %%
import pandas as pd
import requests
from pprint import pprint

# %%
# url variables
breed = 'hound'
sub_breed = 'hound'

# get images by sub-breed
sb_url = f'https://dog.ceo/api/breed/{sub_breed}/list'

# get images by breed
b_url = f'https://dog.ceo/api/breed/{breed}/images'

# get list of all available breeds (sub-breed in list)
all_url = 'https://dog.ceo/api/breeds/list/all'

# %%
# call API for list of sub-breed (2 dictionary items, 1st results, 2nd status)
requests.get(sb_url).json()
# Out:
# {'message': ['afghan',
#   'basset',
#   'blood',
#   'english',
#   'ibizan',
#   'plott',
#   'walker'],
#  'status': 'success'}

# %%
# list of all breeds & sub-breeds (2 dictionary items, 1st results dictionary, 2nd status)
requests.get(all_url).json()
# Out:
# {'message': {'affenpinscher': [],
#   'african': [],
#   'airedale': [],
#   'akita': [],
#   'appenzeller': [],
#   'australian': ['shepherd'],
#   'basenji': [],
#   'beagle': [],
#   'bluetick': [],
#   'borzoi': [],
#   'bouvier': [],
#   'boxer': [],
#   'brabancon': [],
#   'briard': [],
#   'buhund': ['norwegian'],
#   'bulldog': ['boston', 'english', 'french'],
#   'bullterrier': ['staffordshire'],
#   'cairn': [],
#   'cattledog': ['australian'],
#   'chihuahua': [],
#   'chow': [],
#   'clumber': [],
#   'cockapoo': [],
#   'collie': ['border'],
#   'coonhound': [],
#   'corgi': ['cardigan'],
#   'cotondetulear': [],
#   'dachshund': [],
#   'dalmatian': [],
#   'dane': ['great'],
#   'deerhound': ['scottish'],
#   'dhole': [],
#   'dingo': [],
#   'doberman': [],
#   'elkhound': ['norwegian'],
#   'entlebucher': [],
#   'eskimo': [],
#   'finnish': ['lapphund'],
#   'frise': ['bichon'],
#   'germanshepherd': [],
#   'greyhound': ['italian'],
#   'groenendael': [],
# ...
